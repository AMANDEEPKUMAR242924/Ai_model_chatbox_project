# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# Model aur Tokenizer ka naam
model_name = "EleutherAI/gpt-neo-2.7B"

print("Model aur Tokenizer load ho rahe hain... Please wait")

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
device = "cuda" if torch.cuda.is_available() else "cpu"
model = model.to(device)

print("Model ready hai! Ab aap chat kar sakte ho. Exit karne ke liye 'exit' type karo.")

# Chat loop
while True:
    user_input = input("\nYou: ")
    
    if user_input.lower() == "exit":
        print("Chat session khatam hua.")
        break

    # Input ko encode karo
    inputs = tokenizer(user_input, return_tensors="pt").to("cuda")  # Use "cpu" if no GPU

    # Model se response generate karo
    outputs = model.generate(**inputs, max_new_tokens=150)

    # Output decode karo
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)

    print("\nAI:", response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\utils\import_utils.py:2302, in _LazyModule.__getattr__(self, name)
#    2301 try:
# -> 2302     module = self._get_module(self._class_to_module[name])
#    2303     value = getattr(module, name)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\utils\import_utils.py:2332, in _LazyModule._get_module(self, module_name)
#    2331 except Exception as e:
# -> 2332     raise e
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\utils\import_utils.py:2330, in _LazyModule._get_module(self, module_name)
#    2329 try:
# -> 2330     return importlib.import_module("." + module_name, self.__name__)
#    2331 except Exception as e:
#
# File c:\Program Files\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
# ...
